# %% [markdown]
# # KAEM Profiling
# - GPU or TPU

# %%
# Cache Julia depot to Google Drive if mounted, else use default. Recommended to upload local .julia to drive to skip the install. ~/.julia
drive_depot = joinpath(ENV["HOME"], "drive", "MyDrive", "julia_depot")
if isdir(dirname(drive_depot))
    mkpath(drive_depot)
    pushfirst!(DEPOT_PATH, drive_depot)
    @info "Package cache: $drive_depot"
end

using Pkg
Pkg.activate("..")
Pkg.instantiate()
# Out:
#   Activating project at `~/Work/KAEM`

# %%
ENV["PERCEPTUAL"] = "false"
ENV["DEVICE"] = "gpu"

using Random, ConfParser, Lux, Reactant, Enzyme, ComponentArrays, Accessors, Statistics
using Printf, JSON

include("../src/utils.jl");              using .Utils
include("../src/KAEM/KAEM.jl");          using .KAEM_model, .KAEM_model.EBM_Model, .KAEM_model.GeneratorModel
include("../src/KAEM/model_setup.jl");   using .ModelSetup
include("../src/pipeline/optimizer.jl"); using .optimization
include("../src/pipeline/data_utils.jl"); using .DataUtils: get_vision_dataset
include("../src/KAEM/rng.jl");           using .HLOrng
# Out:
# === Device: gpu ===
# === Device: gpu ===
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775768539.884683  466359 service.cc:153] XLA service 0x24f8c240 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1775768539.884707  466359 service.cc:161]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# I0000 00:00:1775768539.885269  466359 se_gpu_pjrt_client.cc:1440] Using BFC allocator.
# I0000 00:00:1775768539.885972  466359 gpu_helpers.cc:141] XLA backend allocating 2923905024 bytes on device 0 for BFCAllocator.
# I0000 00:00:1775768539.886009  466359 gpu_helpers.cc:182] XLA backend will use up to 974635008 bytes on device 0 for CollectiveBFCAllocator.
# I0000 00:00:1775768539.952300  466359 cuda_dnn.cc:461] Loaded cuDNN version 91400
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775768582.984218  466359 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775768586.678153  466359 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# E0000 00:00:1775768588.788274  466359 cuda_executor.cc:1737] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1775768588.806019  466359 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
function setup(; config="../config/nist_config.ini")
    rng = Random.MersenneTwister(1)
    conf = ConfParse(config); parse_conf!(conf)

    dataset, x_shape, _ = get_vision_dataset("MNIST", 1000, 100, 100; img_resize=(32,32), cnn=false)
    model = init_KAEM(dataset, conf, x_shape; rng=rng)
    x, _ = iterate(model.train_loader)
    x = pu(x)
    opt = create_opt(conf)
    model, opt_st, ps, sk, sl, sr = prep_model(model, x, opt; rng=rng, MLIR=false)
    sr = seed_rand(model; rng=rng)

    return model, opt_st, ps, sk, sl, sr, x
end

function bench(f, args...; warmup=3, trials=20)
    compiled = Reactant.@compile f(args...)
    for _ in 1:warmup; compiled(args...); end
    times = [(@elapsed compiled(args...)) * 1000 for _ in 1:trials]
    return compiled, times
end

function report(items)
    @printf("%-20s %10s %10s %10s\n", "Component", "Med(ms)", "Min(ms)", "Max(ms)")
    println("-"^52)
    for (name, f, args) in items
        _, t = bench(f, args...)
        @printf("%-20s %10.3f %10.3f %10.3f\n", name, median(t), minimum(t), maximum(t))
    end
end

"""Extract HLO op names from StableHLO IR and return sorted (op, count, %) table."""
function hlo_op_profile(hlo_str::String)
    ops = String[]
    for line in split(hlo_str, '\n')
        m = match(r"stablehlo\.(\w+)", line)
        m !== nothing && push!(ops, m.captures[1])
    end
    total = length(ops)
    counts = sort(collect(countmap(ops)); by=last, rev=true)
    return [(op, n, 100.0 * n / total) for (op, n) in counts]
end

function countmap(v)
    d = Dict{String,Int}()
    for x in v; d[x] = get(d, x, 0) + 1; end
    return d
end

function print_hlo_profile(name, profile)
    @printf("\n=== %s (%d total ops) ===\n", name, sum(x[2] for x in profile))
    @printf("%-25s %8s %8s\n", "Op", "Count", "%")
    println("-"^43)
    for (op, n, pct) in profile
        @printf("%-25s %8d %7.1f%%\n", op, n, pct)
    end
end
# Out:
# print_hlo_profile (generic function with 1 method)

# %% [markdown]
# ## Profile

# %%
model, opt_st, ps, sk, sl, sr, x = setup()
ebm, gen = model.prior, model.lkhood
z = pu(randn(Float32, ebm.q_size, ebm.p_size, model.batch_size))
z_samp = pu(Float32.(Array(first(model.sample_prior(model, ps, sk, sl, sr)))))

items = [
    ("ebm_forward",   (z,p,s,l) -> ebm(p,s,l,z),
        (z, ps.ebm, sk.ebm, sl.ebm)),
    ("gen_forward",   (p,s,l,z) -> gen.output_activation(first(gen.generator(p,s,l,z))),
        (ps.gen, sk.gen, sl.gen, z)),
    ("quadrature",    (p,s,l,q) -> ebm.quad(ebm,p,s,l,q),
        (ps.ebm, sk.ebm, sl.ebm, sk.quad)),
    ("inv_transform", (m,p,s,l,r) -> m.sample_prior(m,p,s,l,r),
        (model, ps, sk, sl, sr)),
    ("log_prior",     (z,p,s,l,q) -> model.log_prior(z,ebm,p,s,l,q),
        (z_samp, ps.ebm, sk.ebm, sl.ebm, sk.quad)),
    ("generation",    model,
        (ps, sk, Lux.testmode(sl), sr)),
    ("train_step",    (o,p,s,l,x,i,r) -> model.train_step(o,p,s,l,x,i,r),
        (opt_st, ps, sk, sl, x, 1, sr)),
]

device = ENV["DEVICE"]
results = Dict()

for (name, f, args) in items
    _, t = bench(f, args...)

    hlo = string(Reactant.@code_hlo f(args...))
    profile = hlo_op_profile(hlo)

    results[name] = Dict(
        "timing_ms" => Dict("median" => median(t), "min" => minimum(t), "max" => maximum(t)),
        "hlo_ops" => [Dict("op" => op, "count" => n, "pct" => round(pct; digits=1)) for (op, n, pct) in profile],
        "total_ops" => sum(x[2] for x in profile),
    )

    @printf("%-20s  med=%.3f ms  min=%.3f ms  max=%.3f ms\n", name, median(t), minimum(t), maximum(t))
    print_hlo_profile(name, profile)
end

mkpath("profiles")
outfile = "profiles/profile_$(device).json"
open(outfile, "w") do io
    JSON.print(io, Dict("device" => device, "components" => results), 2)
end
println("\nSaved to $outfile")
# Out:
# Resized dataset to (32, 32, 1)
# BoundsError: attempt to access 32×32×1×1100 Array{Float32, 4} at index [1:32, 1:32, 1:1, 1:50000]
#
# Stacktrace:
#  [1] throw_boundserror(A::Array{Float32, 4}, I::Tuple{Base.Slice{…}, Base.Slice{…}, Base.Slice{…}, UnitRange{…}})
#    @ Base ./essentials.jl:15
#  [2] checkbounds
#    @ ./abstractarray.jl:699 [inlined]
#  [3] _getindex
#    @ ./multidimensional.jl:955 [inlined]
#  [4] getindex
#    @ ./abstractarray.jl:1342 [inlined]
#  [5] init_KAEM(dataset::Array{…}, conf::ConfParse, x_shape::Tuple{…}; file_loc::String, rng::MersenneTwister)
#    @ Main.KAEM_model ~/Work/KAEM/src/KAEM/KAEM.jl:88
#  [6] setup(; config::String)
#    @ Main ./In[3]:6
#  [7] setup()
#    @ Main ./In[3]:1
#  [8] top-level scope
#    @ In[4]:1
#  [9] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489
# Some type information was truncated. Use `show(err)` to see complete types.

# %% [markdown]
# ## XLA Trace
# Upload `.pb` to [Perfetto UI](https://ui.perfetto.dev) for per-op runtime breakdown.

# %%
step_fn(o,p,s,l,x,i,r) = model.train_step(o,p,s,l,x,i,r)
compiled, _ = bench(step_fn, opt_st, ps, sk, sl, x, 1, sr; warmup=1, trials=1)

device = ENV["DEVICE"]
tracefile = "profiles/train_step_$(device)"
Reactant.Profiler.with_profiler(tracefile) do
    for _ in 1:20; compiled(opt_st, ps, sk, sl, x, 1, sr); end
end
println("Saved to $(tracefile).pb")
# Out:
# UndefVarError: `opt_st` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[5]:2
#  [2] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489
