# %% [markdown]
# # KAEM Profiling

# %%
# cd("/content")
# isdir("/content/KAEM")
# rm("/content/KAEM", recursive=true, force=true)
# run(`git clone https://github.com/PritRaj1/KAEM.git /content/KAEM`)
# cd("/content/KAEM")
# @assert isfile("Project.toml")
# println("Fresh clone ready at ", pwd())

# # Cache packages to Google Drive if mounted
# drive_depot = joinpath(ENV["HOME"], "drive", "MyDrive", "julia_depot")
# if isdir(dirname(drive_depot))
#     mkpath(drive_depot)
#     pushfirst!(DEPOT_PATH, drive_depot)
#     @info "Package cache: $drive_depot"
# end

# using Pkg; Pkg.activate(pwd()); Pkg.resolve(); Pkg.instantiate()

# %%
ENV["PERCEPTUAL"] = "false"
ENV["DEVICE"] = "gpu"

using Random, ConfParser, Lux, Reactant, Enzyme, ComponentArrays, Accessors, Statistics
using Printf, JSON

cd("..")
include("src/utils.jl");               using .Utils
include("src/KAEM/KAEM.jl");           using .KAEM_model, .KAEM_model.EBM_Model, .KAEM_model.GeneratorModel
include("src/KAEM/model_setup.jl");    using .ModelSetup
include("src/pipeline/optimizer.jl");  using .optimization
include("src/pipeline/data_utils.jl"); using .DataUtils: get_vision_dataset
include("src/KAEM/rng.jl");            using .HLOrng
include("src/KAEM/grid_updating.jl");  using .ModelGridUpdating
# Out:
# === Device: gpu ===
# === Device: gpu ===
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775867734.703461   74576 service.cc:153] XLA service 0xd689690 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1775867734.703497   74576 service.cc:161]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# I0000 00:00:1775867734.705301   74576 se_gpu_pjrt_client.cc:1440] Using BFC allocator.
# I0000 00:00:1775867734.705363   74576 gpu_helpers.cc:141] XLA backend allocating 2923905024 bytes on device 0 for BFCAllocator.
# I0000 00:00:1775867734.705395   74576 gpu_helpers.cc:182] XLA backend will use up to 974635008 bytes on device 0 for CollectiveBFCAllocator.
# I0000 00:00:1775867734.722744   74576 cuda_dnn.cc:461] Loaded cuDNN version 91400
#     CondaPkg Found dependencies: /home/pritmanguy/.julia/packages/CondaPkg/8GjrP/CondaPkg.toml
#     CondaPkg Found dependencies: /home/pritmanguy/.julia/packages/PythonCall/83z4q/CondaPkg.toml
#     CondaPkg Found dependencies: /home/pritmanguy/.julia/packages/HuggingFaceDatasets/ThepL/CondaPkg.toml
#     CondaPkg Found dependencies: /home/pritmanguy/.julia/packages/Reactant/UjybB/CondaPkg.toml
#     CondaPkg Initialising pixi
#              │ /home/pritmanguy/.julia/artifacts/cefba4912c2b400756d043a2563ef77a0088866b/bin/pixi
#              │ init
#              │ --format pixi
#              └ /home/pritmanguy/Work/KAEM/.CondaPkg
# ✔ Created /home/pritmanguy/Work/KAEM/.CondaPkg/pixi.toml
#     CondaPkg Wrote /home/pritmanguy/Work/KAEM/.CondaPkg/pixi.toml
#              │ [dependencies]
#              │ openssl = ">=3, <3.6"
#              │ libstdcxx = ">=3.4,<=15.1"
#              │ uv = ">=0.4"
#              │ libstdcxx-ng = ">=3.4,<=15.1"
#              │ pillow = "*"
#              │ numpy = "*"
#              │ datasets = ">=2.0, <4"
#              │
#              │     [dependencies.python]
#              │     channel = "conda-forge"
#              │     build = "*cp*"
#              │     version = "<=3.12,>=3.9,<4, >=3.10,!=3.14.0,!=3.14.1,<4"
#              │
#              │ [project]
#              │ name = ".CondaPkg"
#              │ platforms = ["linux-64"]
#              │ channels = ["conda-forge"]
#              │ channel-priority = "strict"
#              │ description = "automatically generated by CondaPkg.jl"
#              │
#              │ [pypi-dependencies]
#              │ jax = ">= 0.5"
#              │ numpy = ">= 1, >= 2"
#              └ tensorflow = ">= 2.17"
#     CondaPkg Installing packages
#              │ /home/pritmanguy/.julia/artifacts/cefba4912c2b400756d043a2563ef77a0088866b/bin/pixi
#              │ install
#              └ --manifest-path /home/pritmanguy/Work/KAEM/.CondaPkg/pixi.toml
# ✔ The default environment has been installed.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775867827.137079   74576 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775867830.876853   74576 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# E0000 00:00:1775867833.191185   74576 cuda_executor.cc:1737] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1775867833.205861   74576 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
function setup(; config="config/svhn_config.ini")
    rng = Random.MersenneTwister(1)
    conf = ConfParse(config); parse_conf!(conf)

    batch_size = retrieve(conf, "TRAINING", "batch_size")
    commit!(conf, "TRAINING", "N_train", batch_size)
    commit!(conf, "TRAINING", "N_test", batch_size)

    N = parse(Int, batch_size)
    cnn = parse(Bool, retrieve(conf, "CNN", "use_cnn_lkhood"))
    dataset_name = retrieve(conf, "TRAINING", "dataset")

    dataset, x_shape, _ = get_vision_dataset(dataset_name, N, N, N; img_resize=(32,32), cnn=cnn)
    model = init_KAEM(dataset, conf, x_shape; rng=rng)
    x, _ = iterate(model.train_loader)
    x = pu(x)
    opt = create_opt(conf)
    model, opt_st, ps, sk, sl, sr = prep_model(model, x, opt; rng=rng, MLIR=false)
    sr = seed_rand(model; rng=rng)
    gu = GridUpdater(model, conf)

    return model, opt_st, ps, sk, sl, sr, x, gu
end

function hlo_op_profile(hlo_str::String)
    ops = String[]
    for line in split(hlo_str, '\n')
        m = match(r"stablehlo\.(\w+)", line)
        m !== nothing && push!(ops, m.captures[1])
    end
    total = length(ops)
    d = Dict{String,Int}()
    for x in ops; d[x] = get(d, x, 0) + 1; end
    counts = sort(collect(d); by=last, rev=true)
    return [(op, n, 100.0 * n / total) for (op, n) in counts]
end

function print_hlo_profile(name, profile)
    total = sum(x[2] for x in profile)
    @printf("\n=== %s (%d total ops) ===\n", name, total)
    @printf("%-25s %8s %8s\n", "Op", "Count", "%")
    println("-"^43)
    for (op, n, pct) in profile
        @printf("%-25s %8d %7.1f%%\n", op, n, pct)
    end
end

function profile_and_bench(name, f, args...; warmup=3, trials=10)
    hlo = string(Reactant.@code_hlo f(args...))
    profile = hlo_op_profile(hlo)
    print_hlo_profile(name, profile)

    compiled = Reactant.@compile f(args...)
    for _ in 1:warmup; compiled(args...); end
    times = [(@elapsed compiled(args...)) * 1000 for _ in 1:trials]
    @printf("%-20s  med=%.3f ms  min=%.3f ms  max=%.3f ms\n\n", name, median(times), minimum(times), maximum(times))

    return profile, times, compiled
end
# Out:
# profile_and_bench (generic function with 1 method)

# %% [markdown]
# ## Profile

# %%
model, opt_st, ps, sk, sl, sr, x, gu = setup()
device = ENV["DEVICE"]

# Profile train_step
train_step(o,p,s,l,x,i,r) = model.train_step(o,p,s,l,x,i,r)
ts_profile, ts_times, ts_compiled = profile_and_bench("train_step", train_step, opt_st, ps, sk, sl, x, 1, sr)

# Profile grid_update
grid_update(x,p,s,l,i,r) = gu(x,p,s,l,i,r)
gu_profile, gu_times, _ = profile_and_bench("grid_update", grid_update, x, ps, sk, Lux.testmode(sl), 1, sr)

# Save
mkpath("profiles")
outfile = "profiles/profile_$(device).json"
open(outfile, "w") do io
    JSON.print(io, Dict(
        "device" => device,
        "train_step" => Dict(
            "timing_ms" => Dict("median" => median(ts_times), "min" => minimum(ts_times), "max" => maximum(ts_times)),
            "hlo_ops" => [Dict("op" => op, "count" => n, "pct" => round(pct; digits=1)) for (op, n, pct) in ts_profile],
            "total_ops" => sum(x[2] for x in ts_profile),
        ),
        "grid_update" => Dict(
            "timing_ms" => Dict("median" => median(gu_times), "min" => minimum(gu_times), "max" => maximum(gu_times)),
            "hlo_ops" => [Dict("op" => op, "count" => n, "pct" => round(pct; digits=1)) for (op, n, pct) in gu_profile],
            "total_ops" => sum(x[2] for x in gu_profile),
        ),
    ), 2)
end
println("Saved to $outfile")
# Out:
# Resized dataset to (32, 32, 1)
# Using 1 threads.
# Prior sampler: Mix ITS
# Posterior sampler: Thermo PCNL
#
# === train_step (2053 total ops) ===
# Op                           Count        %
# -------------------------------------------
# reshape                        600    29.2%
# slice                          524    25.5%
# multiply                       170     8.3%
# add                            118     5.7%
# constant                       112     5.5%
# broadcast_in_dim               110     5.4%
# dot_general                     58     2.8%
# subtract                        50     2.4%
# transpose                       46     2.2%
# reduce                          35     1.7%
# compare                         32     1.6%
# negate                          25     1.2%
# divide                          24     1.2%
# convolution                     24     1.2%
# select                          19     0.9%
# maximum                         17     0.8%
# exponential                     14     0.7%
# convert                         13     0.6%
# pad                             12     0.6%
# log                              9     0.4%
# return                           7     0.3%
# concatenate                      6     0.3%
# dynamic_slice                    5     0.2%
# reduce_window                    5     0.2%
# logistic                         4     0.2%
# tanh                             4     0.2%
# reverse                          3     0.1%
# sqrt                             2     0.1%
# sign                             2     0.1%
# while                            1     0.0%
# clamp                            1     0.0%
# abs                              1     0.0%
# train_step            med=1327.966 ms  min=1197.389 ms  max=1331.170 ms
#
#
# === grid_update (1754 total ops) ===
# I0000 00:00:1775868554.140310   74576 dot_merger.cc:476] Merging Dots in computation: region_8.20
# I0000 00:00:1775868554.141111   74576 dot_merger.cc:476] Merging Dots in computation: main.43
# I0000 00:00:1775868554.151650   74576 dot_merger.cc:476] Merging Dots in computation: region_8.20
# I0000 00:00:1775868554.152393   74576 dot_merger.cc:476] Merging Dots in computation: main.43
# I0000 00:00:1775868554.169201   74576 dot_merger.cc:476] Merging Dots in computation: region_8.20.sunk.clone
# I0000 00:00:1775868554.170094   74576 dot_merger.cc:476] Merging Dots in computation: main.43
# I0000 00:00:1775868554.178480   74576 dot_merger.cc:476] Merging Dots in computation: region_8.20.sunk.clone
# I0000 00:00:1775868554.179514   74576 dot_merger.cc:476] Merging Dots in computation: main.43
# I0000 00:00:1775868554.188735   74576 dot_merger.cc:476] Merging Dots in computation: region_8.20.sunk.clone
# I0000 00:00:1775868554.189747   74576 dot_merger.cc:476] Merging Dots in computation: main.43
# I0000 00:00:1775868554.196608   74576 dot_merger.cc:476] Merging Dots in computation: region_8.20.sunk.clone
# I0000 00:00:1775868554.197384   74576 dot_merger.cc:476] Merging Dots in computation: main.43
# I0000 00:00:1775868554.204215   74576 dot_merger.cc:476] Merging Dots in computation: region_8.20.sunk.clone
# I0000 00:00:1775868554.205040   74576 dot_merger.cc:476] Merging Dots in computation: main.43
# I0000 00:00:1775868554.211554   74576 dot_merger.cc:476] Merging Dots in computation: region_8.20.sunk.clone
# I0000 00:00:1775868554.212326   74576 dot_merger.cc:476] Merging Dots in computation: main.43
# Op                           Count        %
# -------------------------------------------
# reshape                        577    32.9%
# slice                          528    30.1%
# multiply                       127     7.2%
# broadcast_in_dim                81     4.6%
# add                             77     4.4%
# constant                        72     4.1%
# subtract                        42     2.4%
# dot_general                     39     2.2%
# transpose                       37     2.1%
# compare                         20     1.1%
# reduce                          18     1.0%
# divide                          17     1.0%
# convolution                     15     0.9%
# negate                          15     0.9%
# maximum                         13     0.7%
# exponential                     12     0.7%
# select                          11     0.6%
# convert                          9     0.5%
# concatenate                      6     0.3%
# return                           6     0.3%
# dynamic_slice                    5     0.3%
# log                              5     0.3%
# reverse                          3     0.2%
# reduce_window                    3     0.2%
# logistic                         3     0.2%
# tanh                             3     0.2%
# triangular_solve                 2     0.1%
# sign                             2     0.1%
# sqrt                             1     0.1%
# while                            1     0.1%
# abs                              1     0.1%
# pad                              1     0.1%
# sort                             1     0.1%
# cholesky                         1     0.1%
# grid_update           med=1291.741 ms  min=1079.793 ms  max=1296.185 ms
# I0000 00:00:1775869049.021072   74576 dot_merger.cc:476] Merging Dots in computation: region_8.19
# I0000 00:00:1775869049.023058   74576 dot_merger.cc:476] Merging Dots in computation: main.25
# I0000 00:00:1775869049.039339   74576 dot_merger.cc:476] Merging Dots in computation: region_8.19
# I0000 00:00:1775869049.041220   74576 dot_merger.cc:476] Merging Dots in computation: main.25
# I0000 00:00:1775869049.090219   74576 dot_merger.cc:476] Merging Dots in computation: region_8.19.sunk.clone
# I0000 00:00:1775869049.092232   74576 dot_merger.cc:476] Merging Dots in computation: main.25
# I0000 00:00:1775869049.105376   74576 dot_merger.cc:476] Merging Dots in computation: region_8.19.sunk.clone
# I0000 00:00:1775869049.107299   74576 dot_merger.cc:476] Merging Dots in computation: main.25
# I0000 00:00:1775869049.119983   74576 dot_merger.cc:476] Merging Dots in computation: region_8.19.sunk.clone
# I0000 00:00:1775869049.121972   74576 dot_merger.cc:476] Merging Dots in computation: main.25
# I0000 00:00:1775869049.134520   74576 dot_merger.cc:476] Merging Dots in computation: region_8.19.sunk.clone
# I0000 00:00:1775869049.136481   74576 dot_merger.cc:476] Merging Dots in computation: main.25
# I0000 00:00:1775869049.148880   74576 dot_merger.cc:476] Merging Dots in computation: region_8.19.sunk.clone
# I0000 00:00:1775869049.150806   74576 dot_merger.cc:476] Merging Dots in computation: main.25
# Saved to profiles/profile_gpu.json

# %% [markdown]
# ## XLA Trace
# Upload `.pb` to [Perfetto UI](https://ui.perfetto.dev) for per-op runtime breakdown.

# %%
device = ENV["DEVICE"]
tracefile = "profiles/train_step_$(device)"
Reactant.Profiler.with_profiler(tracefile) do
    for _ in 1:20; ts_compiled(opt_st, ps, sk, sl, x, 1, sr); end
end
println("Saved to $(tracefile)/")
# Out:
# Saved to profiles/train_step_gpu/
# I0000 00:00:1775869111.855425   74576 profiler_session.cc:103] Profiler session initializing.
# I0000 00:00:1775869111.855522   74576 profiler_session.cc:118] Profiler session started.
# I0000 00:00:1775869111.855679   74576 cupti_tracer.cc:1104] Profiler found 1 GPUs
# I0000 00:00:1775869111.861645   74576 cuda_version_variants.cc:36] CUDA runtime version: 13020
# I0000 00:00:1775869111.861675   74576 cuda_version_variants.cc:52] CUDA driver version: 13020
# I0000 00:00:1775869137.980696   74576 profiler_session.cc:68] Profiler session collecting data.
# I0000 00:00:1775869138.009387   74576 cupti_tracer.cc:1518] CUPTI activity buffer flushed
# I0000 00:00:1775869138.779679   74576 cupti_collector.cc:855]  GpuTracer has collected 44043 callback api events and 64392 activity events.
# I0000 00:00:1775869138.779840   74576 cupti_collector.cc:858]  GpuTracer max callback_events: 2097152, max activity events: 2097152
# I0000 00:00:1775869139.323961   74576 save_profile.cc:150] Collecting XSpace to repository: profiles/train_step_gpu/plugins/profile/2026_04_10_17_58_59/silverback.xplane.pb
# I0000 00:00:1775869141.025531   74576 save_profile.cc:123] Creating directory: profiles/train_step_gpu/plugins/profile/2026_04_10_17_58_59
#
# I0000 00:00:1775869141.874741   74576 save_profile.cc:129] Dumped gzipped tool data for trace.json.gz to profiles/train_step_gpu/plugins/profile/2026_04_10_17_58_59/silverback.trace.json.gz
# I0000 00:00:1775869142.095894   74576 profiler_session.cc:136] Profiler session tear down.
