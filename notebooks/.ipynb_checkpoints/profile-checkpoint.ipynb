# %% [markdown]
# # KAEM Profiling

# %%
# cd("/content")
# isdir("/content/KAEM")
# rm("/content/KAEM", recursive=true, force=true)
# run(`git clone https://github.com/PritRaj1/KAEM.git /content/KAEM`)
# cd("/content/KAEM")
# @assert isfile("Project.toml")
# println("Fresh clone ready at ", pwd())

# # Cache packages to Google Drive if mounted
# drive_depot = joinpath(ENV["HOME"], "drive", "MyDrive", "julia_depot")
# if isdir(dirname(drive_depot))
#     mkpath(drive_depot)
#     pushfirst!(DEPOT_PATH, drive_depot)
#     @info "Package cache: $drive_depot"
# end

# using Pkg; Pkg.activate(pwd()); Pkg.resolve(); Pkg.instantiate()

# %%
ENV["PERCEPTUAL"] = "false"
ENV["DEVICE"] = "gpu"

using Random, ConfParser, Lux, Reactant, Enzyme, ComponentArrays, Accessors, Statistics
using Printf, JSON

cd("..")
include("src/utils.jl");               using .Utils
include("src/KAEM/KAEM.jl");           using .KAEM_model, .KAEM_model.EBM_Model, .KAEM_model.GeneratorModel
include("src/KAEM/model_setup.jl");    using .ModelSetup
include("src/pipeline/optimizer.jl");  using .optimization
include("src/pipeline/data_utils.jl"); using .DataUtils: get_vision_dataset
include("src/KAEM/rng.jl");            using .HLOrng
# Out:
# === Device: gpu ===
# === Device: gpu ===
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775865349.747078   59862 service.cc:153] XLA service 0x38207370 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1775865349.747095   59862 service.cc:161]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# I0000 00:00:1775865349.747408   59862 se_gpu_pjrt_client.cc:1440] Using BFC allocator.
# I0000 00:00:1775865349.747435   59862 gpu_helpers.cc:141] XLA backend allocating 2923905024 bytes on device 0 for BFCAllocator.
# I0000 00:00:1775865349.747455   59862 gpu_helpers.cc:182] XLA backend will use up to 974635008 bytes on device 0 for CollectiveBFCAllocator.
# I0000 00:00:1775865349.769725   59862 cuda_dnn.cc:461] Loaded cuDNN version 91400
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775865402.496837   59862 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775865409.320213   59862 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# E0000 00:00:1775865413.154219   59862 cuda_executor.cc:1737] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1775865413.170157   59862 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
function setup(; config="config/svhn_config.ini")
    rng = Random.MersenneTwister(1)
    conf = ConfParse(config); parse_conf!(conf)

    # Minimal dataset — HLO ops are identical regardless of N_train
    batch_size = retrieve(conf, "TRAINING", "batch_size")
    commit!(conf, "TRAINING", "N_train", batch_size)
    commit!(conf, "TRAINING", "N_test", batch_size)

    N = parse(Int, batch_size)
    cnn = parse(Bool, retrieve(conf, "CNN", "use_cnn_lkhood"))
    dataset_name = retrieve(conf, "TRAINING", "dataset")

    dataset, x_shape, _ = get_vision_dataset(dataset_name, N, N, N; img_resize=(32,32), cnn=cnn)
    model = init_KAEM(dataset, conf, x_shape; rng=rng)
    x, _ = iterate(model.train_loader)
    x = pu(x)
    opt = create_opt(conf)
    model, opt_st, ps, sk, sl, sr = prep_model(model, x, opt; rng=rng, MLIR=false)
    sr = seed_rand(model; rng=rng)

    return model, opt_st, ps, sk, sl, sr, x
end

function hlo_op_profile(hlo_str::String)
    ops = String[]
    for line in split(hlo_str, '\n')
        m = match(r"stablehlo\.(\w+)", line)
        m !== nothing && push!(ops, m.captures[1])
    end
    total = length(ops)
    d = Dict{String,Int}()
    for x in ops; d[x] = get(d, x, 0) + 1; end
    counts = sort(collect(d); by=last, rev=true)
    return [(op, n, 100.0 * n / total) for (op, n) in counts]
end

function print_hlo_profile(profile)
    total = sum(x[2] for x in profile)
    @printf("%-25s %8s %8s\n", "Op", "Count", "%")
    println("-"^43)
    for (op, n, pct) in profile
        @printf("%-25s %8d %7.1f%%\n", op, n, pct)
    end
    println("\nTotal ops: $total")
end
# Out:
# print_hlo_profile (generic function with 1 method)

# %% [markdown]
# ## Profile

# %%
model, opt_st, ps, sk, sl, sr, x = setup()
device = ENV["DEVICE"]

# HLO op profile (no GPU alloc)
train_step(o,p,s,l,x,i,r) = model.train_step(o,p,s,l,x,i,r)
hlo = string(Reactant.@code_hlo train_step(opt_st, ps, sk, sl, x, 1, sr))
profile = hlo_op_profile(hlo)
print_hlo_profile(profile)

# Benchmark
compiled = Reactant.@compile train_step(opt_st, ps, sk, sl, x, 1, sr)
for _ in 1:3; compiled(opt_st, ps, sk, sl, x, 1, sr); end
times = [(@elapsed compiled(opt_st, ps, sk, sl, x, 1, sr)) * 1000 for _ in 1:10]
@printf("\ntrain_step  med=%.3f ms  min=%.3f ms  max=%.3f ms\n", median(times), minimum(times), maximum(times))

# Save
mkpath("profiles")
outfile = "profiles/profile_$(device).json"
open(outfile, "w") do io
    JSON.print(io, Dict(
        "device" => device,
        "timing_ms" => Dict("median" => median(times), "min" => minimum(times), "max" => maximum(times)),
        "hlo_ops" => [Dict("op" => op, "count" => n, "pct" => round(pct; digits=1)) for (op, n, pct) in profile],
        "total_ops" => sum(x[2] for x in profile),
    ), 2)
end
println("Saved to $outfile")
# Out:
# Resized dataset to (32, 32, 1)
# Using 1 threads.
# Prior sampler: Mix ITS
# Posterior sampler: Thermo PCNL
# Op                           Count        %
# -------------------------------------------
# reshape                        585    30.1%
# slice                          524    27.0%
# multiply                       147     7.6%
# broadcast_in_dim               103     5.3%
# add                            101     5.2%
# constant                        90     4.6%
# dot_general                     46     2.4%
# subtract                        44     2.3%
# transpose                       38     2.0%
# compare                         31     1.6%
# reduce                          31     1.6%
# negate                          30     1.5%
# convolution                     24     1.2%
# divide                          23     1.2%
# select                          18     0.9%
# maximum                         17     0.9%
# pad                             15     0.8%
# convert                         13     0.7%
# exponential                     13     0.7%
# log                              8     0.4%
# return                           7     0.4%
# dynamic_slice                    5     0.3%
# concatenate                      5     0.3%
# reduce_window                    5     0.3%
# cosine                           4     0.2%
# sine                             4     0.2%
# logistic                         4     0.2%
# reverse                          3     0.2%
# sqrt                             2     0.1%
# sign                             2     0.1%
# while                            1     0.1%
#
# Total ops: 1943
#
# train_step  med=1277.990 ms  min=1156.104 ms  max=1281.489 ms
# Saved to profiles/profile_gpu.json
# I0000 00:00:1775866438.492085   59862 dot_merger.cc:476] Merging Dots in computation: region_7.18
# I0000 00:00:1775866438.493379   59862 dot_merger.cc:476] Merging Dots in computation: main.39
# I0000 00:00:1775866438.507783   59862 dot_merger.cc:476] Merging Dots in computation: region_7.18
# I0000 00:00:1775866438.508882   59862 dot_merger.cc:476] Merging Dots in computation: main.39
# I0000 00:00:1775866438.535147   59862 dot_merger.cc:476] Merging Dots in computation: region_7.18.sunk.clone
# I0000 00:00:1775866438.536379   59862 dot_merger.cc:476] Merging Dots in computation: main.39
# I0000 00:00:1775866438.545761   59862 dot_merger.cc:476] Merging Dots in computation: region_7.18.sunk.clone
# I0000 00:00:1775866438.547008   59862 dot_merger.cc:476] Merging Dots in computation: main.39
# I0000 00:00:1775866438.555872   59862 dot_merger.cc:476] Merging Dots in computation: region_7.18.sunk.clone
# I0000 00:00:1775866438.557124   59862 dot_merger.cc:476] Merging Dots in computation: main.39
# I0000 00:00:1775866438.566235   59862 dot_merger.cc:476] Merging Dots in computation: region_7.18.sunk.clone
# I0000 00:00:1775866438.567453   59862 dot_merger.cc:476] Merging Dots in computation: main.39
# I0000 00:00:1775866438.575743   59862 dot_merger.cc:476] Merging Dots in computation: region_7.18.sunk.clone
# I0000 00:00:1775866438.576926   59862 dot_merger.cc:476] Merging Dots in computation: main.39
# I0000 00:00:1775866438.585115   59862 dot_merger.cc:476] Merging Dots in computation: region_7.18.sunk.clone
# I0000 00:00:1775866438.586296   59862 dot_merger.cc:476] Merging Dots in computation: main.39

# %% [markdown]
# ## XLA Trace
# Upload `.pb` to [Perfetto UI](https://ui.perfetto.dev) for per-op runtime breakdown.

# %%
device = ENV["DEVICE"]
tracefile = "profiles/train_step_$(device)"
Reactant.Profiler.with_profiler(tracefile) do
    for _ in 1:20; compiled(opt_st, ps, sk, sl, x, 1, sr); end
end
println("Saved to $(tracefile).pb")
# Out:
# Saved to profiles/train_step_gpu.pb
# I0000 00:00:1775866503.732252   59862 profiler_session.cc:103] Profiler session initializing.
# I0000 00:00:1775866503.732324   59862 profiler_session.cc:118] Profiler session started.
# I0000 00:00:1775866503.732516   59862 cupti_tracer.cc:1104] Profiler found 1 GPUs
# I0000 00:00:1775866503.741967   59862 cuda_version_variants.cc:36] CUDA runtime version: 13020
# I0000 00:00:1775866503.742011   59862 cuda_version_variants.cc:52] CUDA driver version: 13020
# I0000 00:00:1775866529.160320   59862 profiler_session.cc:68] Profiler session collecting data.
# I0000 00:00:1775866529.197391   59862 cupti_tracer.cc:1518] CUPTI activity buffer flushed
# I0000 00:00:1775866530.131411   59862 cupti_collector.cc:855]  GpuTracer has collected 39260 callback api events and 54687 activity events.
# I0000 00:00:1775866530.132823   59862 cupti_collector.cc:858]  GpuTracer max callback_events: 2097152, max activity events: 2097152
# I0000 00:00:1775866531.305999   59862 save_profile.cc:150] Collecting XSpace to repository: profiles/train_step_gpu/plugins/profile/2026_04_10_17_15_31/silverback.xplane.pb
# I0000 00:00:1775866533.780359   59862 save_profile.cc:123] Creating directory: profiles/train_step_gpu/plugins/profile/2026_04_10_17_15_31
#
# I0000 00:00:1775866535.294778   59862 save_profile.cc:129] Dumped gzipped tool data for trace.json.gz to profiles/train_step_gpu/plugins/profile/2026_04_10_17_15_31/silverback.trace.json.gz
# I0000 00:00:1775866535.537886   59862 profiler_session.cc:136] Profiler session tear down.
